# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset6.csv')
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#          loguser                                         query  \
# 0        etl_528                               from tbl_111329
# 1        etl_528                               from tbl_127353
# 2        etl_528                               from tbl_128986
# 3        etl_528                               from tbl_155188
# 4        etl_528                                from tbl_48128
# ...          ...                                           ...
# 630073   etl_528                               from tbl_208448
# 630074  etl_2048                               from tbl_160773
# 630075  etl_2048  into tbl_83793,join tbl_83793,from tbl_83792
# 630076  etl_1151                                from tbl_15915
# 630077  etl_2048                                from tbl_83212
#
#         duration_processed                                    query_processed  \
# 0                  240.851                             ['from', 'tbl_111329']
# ...

# %%
alphabet_df = pd.read_csv('encoding.csv')
alphabet_df = alphabet_df.drop('Unnamed: 0', axis=1)
alphabet_df
# Out:
#         code       value
# 0          1  tbl_277855
# 1          2  tbl_135565
# 2          3  tbl_179336
# 3          4  tbl_202104
# 4          5  tbl_267209
# ...      ...         ...
# 39181  39182   tbl_38262
# 39182  39183   tbl_27303
# 39183  39184  tbl_113687
# 39184  39185  tbl_260513
# 39185  39186  tbl_130342
#
# [39186 rows x 2 columns]

# %%
# Делаем из строчки лист
df['coded_query'] = df['coded_query'].apply(lambda x: x.replace('[', '').replace(']', '').replace(',', ' ').split())
df['coded_query'] = df['coded_query'].apply(lambda x: [int(y) for y in x])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-12-77a6b71c7e8b> in <module>
#       1 # Делаем из строчки лист
# ----> 2 df['coded_query'] = df['coded_query'].apply(lambda x: x.replace('[', '').replace(']', '').replace(',', ' ').split())
#       3 df['coded_query'] = df['coded_query'].apply(lambda x: [int(y) for y in x])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-12-77a6b71c7e8b> in <lambda>(x)
#       1 # Делаем из строчки лист
# ...

# %%
df
# Out:
#          loguser                                         query  \
# 0        etl_528                               from tbl_111329
# 1        etl_528                               from tbl_127353
# 2        etl_528                               from tbl_128986
# 3        etl_528                               from tbl_155188
# 4        etl_528                                from tbl_48128
# ...          ...                                           ...
# 630073   etl_528                               from tbl_208448
# 630074  etl_2048                               from tbl_160773
# 630075  etl_2048  into tbl_83793,join tbl_83793,from tbl_83792
# 630076  etl_1151                                from tbl_15915
# 630077  etl_2048                                from tbl_83212
#
#         duration_processed                                    query_processed  \
# 0                  240.851                             ['from', 'tbl_111329']
# ...
